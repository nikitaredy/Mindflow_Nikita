# %%
list=[2,4,6,8,10,12,14]
print(list)
# Out:
# [2, 4, 6, 8, 10, 12, 14]

# %%
list=[3,6,9,12]
list.append(4)
list.append(15)
print(list)
# Out:
# [3, 6, 9, 12, 4, 15]

# %%
list_names=["Akhi", "Nikki", "ashu", "pravs", "mona"]
list_names[2]="Rishi"
print(list_names)
# Out:
# ['Akhi', 'Nikki', 'Rishi', 'pravs', 'mona']

# %%
list=[24,27,17,18,9,6,2]
list.remove(17)
list.remove(6)
print(list)
# Out:
# [24, 27, 18, 9, 2]

# %%
my_dict={'name':'Reshitha', 'Age':'19','City':'Vizag'}
print(my_dict)
# Out:
# {'name': 'Reshitha', 'Age': '19', 'City': 'Vizag'}

# %%
my_dict={}
my_dict['key 1']='Rishi'
my_dict['key 2']='Akhi'
my_dict['key 3']='Nikki'
print(my_dict)
# Out:
# {'key 1': 'Rishi', 'key 2': 'Akhi', 'key 3': 'Nikki'}

# %%
my_dict={'a':2, 'b':8,'c':6, 'd':8,'e':24}
my_dict['b']= 4
print(my_dict)
# Out:
# {'a': 2, 'b': 4, 'c': 6, 'd': 8, 'e': 24}

# %%
my_dict={'a':'Akhi','b':'Rishi','c':'john','d':'Nikki'}
del my_dict['c']
print(my_dict)
# Out:
# {'a': 'Akhi', 'b': 'Rishi', 'd': 'Nikki'}

# %%
my_set={2,4,6,8,10,12}
print(my_set)
# Out:
# {2, 4, 6, 8, 10, 12}

# %%
my_set={3,6,9}
my_set |={12,15}
print(my_set)
# Out:
# {3, 6, 9, 12, 15}

# %%
my_set={2,4,6,8,12,24}
my_set.remove(12)
my_set.remove(8)
print(my_set)
# Out:
# {2, 4, 6, 24}
